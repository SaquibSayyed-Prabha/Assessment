# %% [markdown]
# # *PANDAS MINI PROJECT*

# %% [markdown]
# ---
# ### PART 1 : Load Dataset

# %%
# 1. Import Pandas. 
import pandas as pd

# %%
# 2. Load the CSV file. 
df = pd.read_csv("student_performance.csv")

# %%
# 3. Display the complete dataset. 
print(df)
# Out:
#     Student_ID   Name   Age  Gender    City        Course  Attendance  Marks  \
# 0          101    Raj  21.0    Male    Pune        Python        90.0   85.0
# 1          102   Amit  22.0    Male  Mumbai            AI        80.0   75.0
# 2          103  Priya  20.0  Female  Nashik        Python        95.0   92.0
# 3          104  Sneha  23.0  Female    Pune  Data Science        88.0   81.0
# 4          105  Rahul  21.0    Male  Mumbai            AI        75.0   65.0
# 5          106  Pooja  22.0  Female    Pune        Python        98.0   96.0
# 6          107  Karan  20.0    Male  Nashik  Data Science        82.0   79.0
# 7          108   Neha  21.0  Female    Pune            AI        91.0   89.0
# 8          109  Akash  24.0    Male  Mumbai        Python        85.0   72.0
# 9          110  Komal  23.0  Female    Pune  Data Science        96.0   94.0
# 10         111  Vikas   NaN    Male    Pune        Python        90.0    NaN
# ...

# %% [markdown]
# ---
# ### PART 2 : Data Exploration

# %%
# 1. Display first 5 rows. 
print(df.head())
# Out:
#    Student_ID   Name   Age  Gender    City        Course  Attendance  Marks  \
# 0         101    Raj  21.0    Male    Pune        Python        90.0   85.0
# 1         102   Amit  22.0    Male  Mumbai            AI        80.0   75.0
# 2         103  Priya  20.0  Female  Nashik        Python        95.0   92.0
# 3         104  Sneha  23.0  Female    Pune  Data Science        88.0   81.0
# 4         105  Rahul  21.0    Male  Mumbai            AI        75.0   65.0
#
#   Purchased
# 0       Yes
# 1        No
# 2       Yes
# 3       Yes
# 4        No

# %%
# 2. Display last 5 rows. 
print(df.tail())
# Out:
#     Student_ID   Name   Age  Gender    City        Course  Attendance  Marks  \
# 8          109  Akash  24.0    Male  Mumbai        Python        85.0   72.0
# 9          110  Komal  23.0  Female    Pune  Data Science        96.0   94.0
# 10         111  Vikas   NaN    Male    Pune        Python        90.0    NaN
# 11         112   Riya  22.0  Female  Mumbai            AI         NaN   85.0
# 12         113    Raj  21.0    Male    Pune        Python        90.0   85.0
#
#    Purchased
# 8         No
# 9        Yes
# 10       Yes
# 11        No
# 12        Yes

# %%
# 3. Display dataset shape. 
print(df.shape)
# Out:
# (13, 9)

# %%
# 4. Display all column names. 
print(df.columns)
# Out:
# Index(['Student_ID', 'Name', 'Age', 'Gender', 'City', 'Course', 'Attendance',
#        'Marks', 'Purchased '],
#       dtype='str')

# %%
# 5. Display data types. 
print(df.dtypes)
# Out:
# Student_ID      int64
# Name              str
# Age           float64
# Gender            str
# City              str
# Course            str
# Attendance    float64
# Marks         float64
# Purchased         str
# dtype: object

# %%
# 6. Display dataset information. 
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Student_ID  13 non-null     int64
#  1   Name        13 non-null     str
#  2   Age         12 non-null     float64
#  3   Gender      13 non-null     str
#  4   City        13 non-null     str
#  5   Course      13 non-null     str
#  6   Attendance  12 non-null     float64
#  7   Marks       12 non-null     float64
#  8   Purchased   13 non-null     str
# dtypes: float64(3), int64(1), str(5)
# memory usage: 1.0 KB
# None

# %%
# 7. Display statistical summary. 
print(df.describe())
# Out:
#        Student_ID        Age  Attendance      Marks
# count    13.00000  12.000000   12.000000  12.000000
# mean    107.00000  21.666667   88.333333  83.166667
# std       3.89444   1.230915    6.813534   9.281784
# min     101.00000  20.000000   75.000000  65.000000
# 25%     104.00000  21.000000   84.250000  78.000000
# 50%     107.00000  21.500000   90.000000  85.000000
# 75%     110.00000  22.250000   92.000000  89.750000
# max     113.00000  24.000000   98.000000  96.000000

# %% [markdown]
# ---
# ### PART 3 : Data Cleaning

# %%
# 1. Find missing values. 
print(df.isnull())
# Out:
#     Student_ID   Name    Age  Gender   City  Course  Attendance  Marks  \
# 0        False  False  False   False  False   False       False  False
# 1        False  False  False   False  False   False       False  False
# 2        False  False  False   False  False   False       False  False
# 3        False  False  False   False  False   False       False  False
# 4        False  False  False   False  False   False       False  False
# 5        False  False  False   False  False   False       False  False
# 6        False  False  False   False  False   False       False  False
# 7        False  False  False   False  False   False       False  False
# 8        False  False  False   False  False   False       False  False
# 9        False  False  False   False  False   False       False  False
# 10       False  False   True   False  False   False       False   True
# 11       False  False  False   False  False   False        True  False
# ...

# %%
# 2. Count missing values. 
print(df.isnull().sum())
# Out:
# Student_ID    0
# Name          0
# Age           1
# Gender        0
# City          0
# Course        0
# Attendance    1
# Marks         1
# Purchased     0
# dtype: int64

# %%
# 3. Fill missing values in Age using the average age. 
avg_age = df["Age"].mean()
df["Age"] = df["Age"].fillna(avg_age)

print(df)
# Out:
#     Student_ID   Name        Age  Gender    City        Course  Attendance  \
# 0          101    Raj  21.000000    Male    Pune        Python        90.0
# 1          102   Amit  22.000000    Male  Mumbai            AI        80.0
# 2          103  Priya  20.000000  Female  Nashik        Python        95.0
# 3          104  Sneha  23.000000  Female    Pune  Data Science        88.0
# 4          105  Rahul  21.000000    Male  Mumbai            AI        75.0
# 5          106  Pooja  22.000000  Female    Pune        Python        98.0
# 6          107  Karan  20.000000    Male  Nashik  Data Science        82.0
# 7          108   Neha  21.000000  Female    Pune            AI        91.0
# 8          109  Akash  24.000000    Male  Mumbai        Python        85.0
# 9          110  Komal  23.000000  Female    Pune  Data Science        96.0
# 10         111  Vikas  21.666667    Male    Pune        Python        90.0
# ...

# %%
# 4. Fill missing values in Marks using the average marks. 
avg_marks = df["Marks"].mean()
df["Marks"] = df["Marks"].fillna(avg_marks)

print(df)
# Out:
#     Student_ID   Name        Age  Gender    City        Course  Attendance  \
# 0          101    Raj  21.000000    Male    Pune        Python        90.0
# 1          102   Amit  22.000000    Male  Mumbai            AI        80.0
# 2          103  Priya  20.000000  Female  Nashik        Python        95.0
# 3          104  Sneha  23.000000  Female    Pune  Data Science        88.0
# 4          105  Rahul  21.000000    Male  Mumbai            AI        75.0
# 5          106  Pooja  22.000000  Female    Pune        Python        98.0
# 6          107  Karan  20.000000    Male  Nashik  Data Science        82.0
# 7          108   Neha  21.000000  Female    Pune            AI        91.0
# 8          109  Akash  24.000000    Male  Mumbai        Python        85.0
# 9          110  Komal  23.000000  Female    Pune  Data Science        96.0
# 10         111  Vikas  21.666667    Male    Pune        Python        90.0
# ...

# %%
# 5. Fill missing values in Attendance using the average attendance. 
avg_attendance = df["Attendance"].mean()
df["Attendance"] = df["Attendance"].fillna(avg_attendance)

print(df)
# Out:
#     Student_ID   Name        Age  Gender    City        Course  Attendance  \
# 0          101    Raj  21.000000    Male    Pune        Python   90.000000
# 1          102   Amit  22.000000    Male  Mumbai            AI   80.000000
# 2          103  Priya  20.000000  Female  Nashik        Python   95.000000
# 3          104  Sneha  23.000000  Female    Pune  Data Science   88.000000
# 4          105  Rahul  21.000000    Male  Mumbai            AI   75.000000
# 5          106  Pooja  22.000000  Female    Pune        Python   98.000000
# 6          107  Karan  20.000000    Male  Nashik  Data Science   82.000000
# 7          108   Neha  21.000000  Female    Pune            AI   91.000000
# 8          109  Akash  24.000000    Male  Mumbai        Python   85.000000
# 9          110  Komal  23.000000  Female    Pune  Data Science   96.000000
# 10         111  Vikas  21.666667    Male    Pune        Python   90.000000
# ...

# %%
# 6. Verify that no missing values exist. 
print(df.isnull())
# Out:
#     Student_ID   Name    Age  Gender   City  Course  Attendance  Marks  \
# 0        False  False  False   False  False   False       False  False
# 1        False  False  False   False  False   False       False  False
# 2        False  False  False   False  False   False       False  False
# 3        False  False  False   False  False   False       False  False
# 4        False  False  False   False  False   False       False  False
# 5        False  False  False   False  False   False       False  False
# 6        False  False  False   False  False   False       False  False
# 7        False  False  False   False  False   False       False  False
# 8        False  False  False   False  False   False       False  False
# 9        False  False  False   False  False   False       False  False
# 10       False  False  False   False  False   False       False  False
# 11       False  False  False   False  False   False       False  False
# ...

# %% [markdown]
# ---
# ### PART 4 : Duplicate Records

# %%
# 1. Find duplicate rows. 
print(df[df.duplicated()])
# Out:
# Empty DataFrame
# Columns: [Student_ID, Name, Age, Gender, City, Course, Attendance, Marks, Purchased ]
# Index: []

# %%
# 2. Count duplicate rows.

# %%
# 3. Remove duplicate rows.

# %%
# 4. Display the cleaned dataset.
